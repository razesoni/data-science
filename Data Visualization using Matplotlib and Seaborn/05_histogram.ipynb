# %%
import matplotlib.pyplot as plt

# %%
data = [12, 3,39, 43, 32, 23, 45, 42, 43, 45, 34, 54, 45, 34, 65, 34, 54, 34,4, 29, 40, 65, 23 ,29, 74]

# %%
plt.hist(data, bins=5, edgecolor="black")
plt.axvline(38, color='red', linestyle='--', linewidth=2, label="Average")
plt.xlabel("Marks")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
