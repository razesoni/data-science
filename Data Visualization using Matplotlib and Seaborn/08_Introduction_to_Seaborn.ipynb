# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style='darkgrid')

# %%
x = np.array([1, 3, 4, 5, 6, 7, 8, 9, 10])

# %%
y = np.sin(x)

# %%
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >
