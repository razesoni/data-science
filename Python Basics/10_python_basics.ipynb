# %%
l = [3, 5, 7, 23]

# %%
l[3]
# Out:
# 23

# %%
l[0] = 4

# %%
l
# Out:
# [4, 5, 7, 23]

# %%
l.append(9)

# %%
l
# Out:
# [4, 5, 7, 23, 9]

# %%
l2 = [5, 7]

# %%
l.extend(l2)

# %%
l
# Out:
# [4, 5, 7, 23, 9, 5, 7]

# %%
l.insert(1, 200)

# %%
l
# Out:
# [4, 200, 5, 7, 23, 9, 5, 7]

# %%
num = l.pop(4)
num
# Out:
# 23

# %%
l
# Out:
# [4, 200, 5, 7, 9, 5, 7]

# %%
l.index(200)
# Out:
# 1

# %%
l.count(7)
# Out:
# 2

# %%
l.sort()

# %%
l
# Out:
# [4, 5, 5, 7, 7, 9, 200]

# %%
newl = [2, 5, 3, 9]

# %%
sorted(newl)
# Out:
# [2, 3, 5, 9]

# %%
newl
# Out:
# [2, 5, 3, 9]

# %%
y = [1, 2 , True, False, [2, 4]]

# %%
y
# Out:
# [1, 2, True, False, [2, 4]]

# %%
y[4]
# Out:
# [2, 4]

# %%
y[4][1]
# Out:
# 4

# %%
y + l
# Out:
# [1, 2, True, False, [2, 4], 4, 5, 5, 7, 7, 9, 200]

# %%
if 5 in l:
    print("yes")
# Out:
# yes

# %%
2 in l
# Out:
# False

# %%
s = "akash-ak47-ald-alsal"

# %%
s
# Out:
# 'akash-ak47-ald-alsal'

# %%
s.split("-")
# Out:
# ['akash', 'ak47', 'ald', 'alsal']
