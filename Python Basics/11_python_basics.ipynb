# %%
e = ()
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
t = (3, 4, 6, 7)

# %%
t
# Out:
# (3, 4, 6, 7)

# %%
len(t)
# Out:
# 4

# %%
t[0]
# Out:
# 3

# %%
person = ("Akash", 20, "Engineer")

# %%
name, age, profession = person

# %%
name
# Out:
# 'Akash'

# %%
age
# Out:
# 20

# %%
profession
# Out:
# 'Engineer'
