# %%
a = 10
b = 5

# %%
a + b
# Out:
# 15

# %%
a//b
# Out:
# 2

# %%
a/b
# Out:
# 2.0

# %%
2**5
# Out:
# 32

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
a = 45

# %%
a += 4

# %%
a
# Out:
# 53
