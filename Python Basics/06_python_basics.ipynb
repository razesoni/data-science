# %%
a = 4

# %%
if(a>53):
    print("Greater")
elif(a==4):
    print("Equal")
else:
    print("Smaller")
# Out:
# Equal

# %%
def avg(a, b=4): #b default argument
    return (a + b)/2

# %%
avg(2, 3)
# Out:
# 2.5

# %%
def great():
    print("Great")

# %%
great()
# Out:
# Great
