# %%
a = {}

# %%
type(a)
# Out:
# dict

# %%
b = set()

# %%
type(b)
# Out:
# set

# %%
s = {2, 4, 7, 8, 2}

# %%
s
# Out:
# {2, 4, 7, 8}

# %%
s.add(34)

# %%
s
# Out:
# {2, 4, 7, 8, 34}

# %%
s.update([4, 64, 233])

# %%
s
# Out:
# {2, 4, 7, 8, 34, 64, 233}

# %%
s.remove(4)

# %%
s
# Out:
# {2, 7, 8, 34, 64, 233}

# %%
s.discard(200)

# %%
s
# Out:
# {2, 7, 8, 34, 64, 233}

# %%
l = {2, 7, 59, 20}

# %%
s.union(l)
# Out:
# {2, 7, 8, 20, 34, 59, 64, 233}

# %%
s.intersection(l)
# Out:
# {2, 7}

# %%
s2 = {2, 7, 8}

# %%
s.issubset(s2)
# Out:
# False

# %%
s2.issubset(s)
# Out:
# True

# %%
s.issuperset(s2)
# Out:
# True
