# %%
student = {
    "name":"Akash",
    "age":"25",
    "grade":"A"
}

# %%
student["name"]
# Out:
# 'Akash'

# %%
r = student.get("name4")

# %%
r

# %%
print(r)
# Out:
# None

# %%
student = {
    "name":"Akash",
    "age":"25",
    "grade":"A"
}

# %%
print(student["age"])
# Out:
# 25

# %%
student["age"] = 67
print(student["age"])
# Out:
# 67

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Akash', 67, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Akash'), ('age', 67), ('grade', 'A')])

# %%
student.update({"name":"Harry","language":"python"})

# %%
student
# Out:
# {'name': 'Harry', 'age': 67, 'grade': 'A', 'language': 'python'}

# %%
student.setdefault("age",)
# Out:
# 67
