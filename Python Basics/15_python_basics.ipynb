# %%
import json

# %%
obj = {"name":"Akash", "age":"20", "lang":"python"}
s = json.dumps(obj)
type(s)
print(s)
# Out:
# {"name": "Akash", "age": "20", "lang": "python"}

# %%
d = json.loads('{"name":"Akash", "age":"20", "lang":"python"}')

# %%
type(d)
# Out:
# dict

# %%
print(d)
# Out:
# {'name': 'Akash', 'age': '20', 'lang': 'python'}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'lang'])

# %%
file = open("data.json", "w")

# %%
json.dump(obj, file)

# %%
file.close()
