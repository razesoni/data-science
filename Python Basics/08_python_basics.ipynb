# %%
s = "Akash"

# %%
s[0]
# Out:
# 'A'

# %%
age = 20

# %%
print("My name is {} and I am {} years old".format(s, age))
# Out:
# My name is Akash and I am 20 years old

# %%
print(f"My name is {s} and I am {age} years old")
# Out:
# My name is Akash and I am 20 years old

# %%
print(f"{'Python':<10}") #left align
print(f"{'Python':>10}") # right align
print(f"{'Python':^10}") #center align
# Out:
# Python
#     Python
#   Python
