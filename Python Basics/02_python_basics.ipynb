# %%
name = "Akash"

# %%
name.upper()
# Out:
# 'AKASH'

# %%
name.endswith("sh")
# Out:
# True

# %%
name.lower()
# Out:
# 'akash'

# %%
name.count("a")
# Out:
# 1

# %%
print(len(name))
# Out:
# 5

# %%
man = "   go  "

# %%
man.strip()
# Out:
# 'go'

# %%
s = "Hello World"

# %%
s.replace("World", "Python")
# Out:
# 'Hello Python'

# %%
s.split("hello")
# Out:
# ['Hello World']

# %%
s.join(name)
# Out:
# 'AHello WorldkHello WorldaHello WorldsHello Worldh'

# %%
sy = ["hello", "world"]

# %%
" ".join(sy)
# Out:
# 'hello world'
