# %%
a=5

# %%
b=32

# %%
a+b
# Out:
# 37

# %%
str = "Akash"

# %%
print("Hello World")
# Out:
# Hello World

# %%
# this a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(str))
# Out:
# <class 'str'>

# %%
a= "121"

# %%
b = "1213"

# %%
a + b
# Out:
# '1211213'

# %%
int(a) + int(b)
# Out:
# 1334
